# %%
import mne

raw = mne.io.read_raw_eeglab(
    "../data/raw/OpenNeuro_ds004584/sub-001/eeg/sub-001_task-Rest_eeg.set",
    preload=True
)

print(raw)
print(raw.info["sfreq"])
print(len(raw.ch_names))
# Out:
# Reading d:\Academic\Semester 7\CO425\e20-4yp-Lightweight-Deep-Learning-Models-for-Detection-of-Neurological-Disorders-Using-EEG-Signals\code\Parkinsons\experiments\..\data\OpenNeuro_ds004584\sub-001\eeg\sub-001_task-Rest_eeg.fdt
# Reading 0 ... 140829  =      0.000 ...   281.658 secs...
# <RawEEGLAB | sub-001_task-Rest_eeg.fdt, 63 x 140830 (281.7 s), ~67.8 MiB, data loaded>
# 500.0
# 63
# C:\Users\MSI\AppData\Local\Temp\ipykernel_22480\3671085760.py:3: RuntimeWarning: The data contains 'boundary' events, indicating data discontinuities. Be cautious of filtering and epoching around these events.
#   raw = mne.io.read_raw_eeglab(
