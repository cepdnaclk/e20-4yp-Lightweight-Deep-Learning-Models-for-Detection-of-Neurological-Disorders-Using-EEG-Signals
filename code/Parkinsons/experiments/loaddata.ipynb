# %%
import mne

raw = mne.io.read_raw_eeglab(
    "../data/OpenNeuro_ds004584/sub-001/eeg/sub-001_task-Rest_eeg.set",
    preload=True
)

print(raw)
print(raw.info["sfreq"])
print(len(raw.ch_names))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import mne
# ----> 3 raw = mne.io.read_raw_eeglab(
#       4     "data/OpenNeuro_ds004584/sub-001/eeg/sub-001_task-Rest_eeg.set",
#       5     preload=True
#       6 )
#       8 print(raw)
#       9 print(raw.info["sfreq"])
#
# File c:\Users\MSI\AppData\Local\Programs\Python\Python311\Lib\site-packages\mne\io\eeglab\eeglab.py:328, in read_raw_eeglab(input_fname, eog, preload, uint16_codec, montage_units, verbose)
#     284 @fill_doc
#     285 def read_raw_eeglab(
#     286     input_fname,
#    (...)    291     verbose=None,
#     292 ) -> "RawEEGLAB":
#     293     r"""Read an EEGLAB .set file.
#     294
#     295     Parameters
#    (...)    326     .. versionadded:: 0.11.0
#     327     """
# --> 328     return RawEEGLAB(
#     329         input_fname=input_fname,
# ...
